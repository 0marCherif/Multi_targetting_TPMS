# %%
# !unzip /content/archives.zip
# Out:
# 'unzip' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
for path in os.walk('archives/'):
    print(path)
# Out:
# ('archives/archives', [], ['~A.B._Siddique1.jsonl', '~A._Sophia_Koepke1.jsonl', '~A._Tuan_Nguyen1.jsonl', '~Aadil_Oufkir1.jsonl', '~Aaditya_Singh1.jsonl', '~Aahlad_Manas_Puli1.jsonl', '~Aakanksha_Chowdhery1.jsonl', '~Aakash_Kaku1.jsonl', '~Aaqib_Saeed1.jsonl', '~Aaron_David_Tucker1.jsonl', '~Aaron_Defazio1.jsonl', '~Aaron_J_Snoswell1.jsonl', '~Aaron_Lou1.jsonl', '~Aaron_Mishkin1.jsonl', '~Aaron_M_Ferber1.jsonl', '~Aaron_Sidford1.jsonl', '~Aaron_Zweig2.jsonl', '~Aarshvi_Gajjar1.jsonl', '~Aayam_Kumar_Shrestha1.jsonl', '~Aayush_Mudgal1.jsonl', '~Abbas_Masoumzadeh1.jsonl', '~Abdelaziz_Djelouah2.jsonl', '~Abdulkadir_Canatar1.jsonl', '~Abdullah_Jamal_Hamdi1.jsonl', '~Abdullah_Omar_Alomar1.jsonl', '~Abdulla_Jasem_Almansoori1.jsonl', '~Abdul_Fatir_Ansari2.jsonl', '~Abdurakhmon_Sadiev1.jsonl', '~Abdus_Salam_Azad1.jsonl', '~Abhijeet_Awasthi1.jsonl', '~Abhijin_Adiga1.jsonl', '~Abhijith_Jayakumar1.jsonl', '~Abhilash_Shankarampeta1.jsonl', '~Abhinav_Agrawal1.jsonl', '~Abhinav_Joshi1.jsonl', '~Abhinav_Kumar6.jsonl', '~Abhineet_Agarwal1.jsonl', '~Abhin_Shah1.jsonl', '~Abhipsa_Basu1.jsonl', '~Abhiram_Gnanasambandam1.jsonl', '~Abhishek_Aich1.jsonl', '~Abhishek_Kumar1.jsonl', '~Abhishek_Nadgeri1.jsonl', '~Abhishek_Rao1.jsonl', '~Abhishek_Roy1.jsonl', '~Abhishek_Sharma6.jsonl', '~Abhishek_Shetty1.jsonl', '~Abhishek_Singh1.jsonl', '~Abhishek_Sinha3.jsonl', '~Abhi_Gupta1.jsonl', '~Abir_Das4.jsonl', '~Abir_De1.jsonl', '~Abishek_Sankararaman1.jsonl', '~Abner_Guzman_Guzman-Rivera1.jsonl', '~ABULIKEMU_ABUDUWEILI1.jsonl', '~Achim_Rettinger1.jsonl', '~Adams_Wai-Kin_Kong1.jsonl', '~Adam_Arany1.jsonl', '~Adam_Craig_Pocock1.jsonl', '~Adam_D._Cobb1.jsonl', '~Adam_Earle1.jsonl', '~Adam_Eck1.jsonl', '~Adam_Foster1.jsonl', '~Adam_Goodge1.jsonl', '~Adam_Ibrahim1.jsonl', '~Adam_Joseph_Riesselman1.jsonl', '~Adam_Lilja1.jsonl', '~Adam_Michael_Johansen1.jsonl', '~Adam_Polak1.jsonl', '~Adam_Prugel-Bennett1.jsonl', '~Adam_Scibior1.jsonl', '~Adam_Sealfon1.jsonl', '~Adam_Villaflor1.jsonl', '~Adam_W_Harley1.jsonl', '~Adarsh_Subbaswamy1.jsonl', '~Adel_Nabli1.jsonl', '~Adhiraj_Ghosh2.jsonl', '~Adhyyan_Manish_Narang1.jsonl', '~Adil_Zouitine1.jsonl', '~Aditi_Jha1.jsonl', '~Aditi_Krishnapriyan1.jsonl', '~Aditi_Mavalankar1.jsonl', '~Aditya_Balu1.jsonl', '~Aditya_Chattopadhyay1.jsonl', '~Aditya_Desai2.jsonl', '~Aditya_Ganeshan1.jsonl', '~Aditya_Gilra1.jsonl', '~Aditya_Golatkar1.jsonl', '~Aditya_Kanade2.jsonl', '~Aditya_Kumar_Akash1.jsonl', '~Aditya_Kusupati1.jsonl', '~Aditya_Makkar1.jsonl', '~Aditya_Modi1.jsonl', '~Aditya_Paliwal1.jsonl', '~Aditya_Prakash1.jsonl', '~Aditya_Ramesh2.jsonl', '~Aditya_Shrikant_Mate1.jsonl', '~Aditya_Vardhan_Varre1.jsonl', '~Adi_Haviv1.jsonl', '~Adnan_Siraj_Rakin2.jsonl', '~Adrian_Benton1.jsonl', '~Adrian_Bulat1.jsonl', '~Adriel_Saporta1.jsonl', '~Adrien_Bardes1.jsonl', '~Adrien_Benamira1.jsonl', '~Adrien_Corenflos1.jsonl', '~Adrien_Vacher1.jsonl', '~Advait_Harshal_Gadhikar1.jsonl', '~Advait_U_Parulekar1.jsonl', '~Adway_Mitra1.jsonl', '~Aerin_Kim1.jsonl', '~Afifa_Abduljabbar_Qahtan_Khaled1.jsonl', '~Afroditi_Papadaki1.jsonl', '~Afshin_Oroojlooyjadid1.jsonl', '~Aghiles_Salah1.jsonl', '~Agnieszka_Falenska1.jsonl', '~Ahana_Ghosh1.jsonl', '~Ahcene_Boubekki1.jsonl', '~Ahmad_Kazmi1.jsonl', '~Ahmad_Rashid1.jsonl', '~Ahmed_Abbas1.jsonl', '~Ahmed_Abdelkader_Abdelrazek1.jsonl', '~Ahmed_Elgohary3.jsonl', '~Ahmed_Khaled1.jsonl', '~Ahmed_MAZARI1.jsonl', '~Ahmet_Alacaoglu2.jsonl', '~Ahmet_Iscen3.jsonl', '~Aidan_Scannell1.jsonl', '~Aidong_Zhang2.jsonl', '~Aiham_Taleb1.jsonl', '~Aijun_Zhang2.jsonl', '~Ailing_Zeng1.jsonl', '~Ainhize_Barrainkua1.jsonl', '~Aiping_Liu1.jsonl', '~Aiqing_Zhu1.jsonl', '~Aishan_Liu1.jsonl', '~Aishwarya_Kamath1.jsonl', '~Aivar_Sootla1.jsonl', '~Ajaykumar_Unagar1.jsonl', '~Ajay_Divakaran1.jsonl', '~Ajay_Jaiswal1.jsonl', '~Ajil_Jalal1.jsonl', '~Ajinkya_K_Mulay2.jsonl', '~Ajinkya_Tejankar1.jsonl', '~Ajitesh_Srivastava1.jsonl', '~AJ_Piergiovanni1.jsonl', '~Akash_Abdu_Jyothi1.jsonl', '~Akash_Kumar_Dhaka1.jsonl', '~Akbir_Khan1.jsonl', '~Akhilan_ ...

# %%
import os
liste_dicos=[]
for path,dirname,filename in os.walk('archives/archives'):
  print(filename)
  for afile in filename:
    with open(os.path.join(path,afile)) as f:
      for line in f:
        try:
          a=eval(line)['content']
          liste_dicos.append((afile[:-6],a['title'],a['abstract']))
        except:
          continue


#      mondico[str(afile)]=eval()



#  ainspecter=pd.read_json(os.path.join(path,filename[0]),lines=True)

  #with open(os.path.join(path,filename[0])) as f:
  #  for line in f:
# Out:
# ['~A.B._Siddique1.jsonl', '~A._Sophia_Koepke1.jsonl', '~A._Tuan_Nguyen1.jsonl', '~Aadil_Oufkir1.jsonl', '~Aaditya_Singh1.jsonl', '~Aahlad_Manas_Puli1.jsonl', '~Aakanksha_Chowdhery1.jsonl', '~Aakash_Kaku1.jsonl', '~Aaqib_Saeed1.jsonl', '~Aaron_David_Tucker1.jsonl', '~Aaron_Defazio1.jsonl', '~Aaron_J_Snoswell1.jsonl', '~Aaron_Lou1.jsonl', '~Aaron_Mishkin1.jsonl', '~Aaron_M_Ferber1.jsonl', '~Aaron_Sidford1.jsonl', '~Aaron_Zweig2.jsonl', '~Aarshvi_Gajjar1.jsonl', '~Aayam_Kumar_Shrestha1.jsonl', '~Aayush_Mudgal1.jsonl', '~Abbas_Masoumzadeh1.jsonl', '~Abdelaziz_Djelouah2.jsonl', '~Abdulkadir_Canatar1.jsonl', '~Abdullah_Jamal_Hamdi1.jsonl', '~Abdullah_Omar_Alomar1.jsonl', '~Abdulla_Jasem_Almansoori1.jsonl', '~Abdul_Fatir_Ansari2.jsonl', '~Abdurakhmon_Sadiev1.jsonl', '~Abdus_Salam_Azad1.jsonl', '~Abhijeet_Awasthi1.jsonl', '~Abhijin_Adiga1.jsonl', '~Abhijith_Jayakumar1.jsonl', '~Abhilash_Shankarampeta1.jsonl', '~Abhinav_Agrawal1.jsonl', '~Abhinav_Joshi1.jsonl', '~Abhinav_Kumar6.jsonl', '~Abhineet_Agarwal1.jsonl', '~Abhin_Shah1.jsonl', '~Abhipsa_Basu1.jsonl', '~Abhiram_Gnanasambandam1.jsonl', '~Abhishek_Aich1.jsonl', '~Abhishek_Kumar1.jsonl', '~Abhishek_Nadgeri1.jsonl', '~Abhishek_Rao1.jsonl', '~Abhishek_Roy1.jsonl', '~Abhishek_Sharma6.jsonl', '~Abhishek_Shetty1.jsonl', '~Abhishek_Singh1.jsonl', '~Abhishek_Sinha3.jsonl', '~Abhi_Gupta1.jsonl', '~Abir_Das4.jsonl', '~Abir_De1.jsonl', '~Abishek_Sankararaman1.jsonl', '~Abner_Guzman_Guzman-Rivera1.jsonl', '~ABULIKEMU_ABUDUWEILI1.jsonl', '~Achim_Rettinger1.jsonl', '~Adams_Wai-Kin_Kong1.jsonl', '~Adam_Arany1.jsonl', '~Adam_Craig_Pocock1.jsonl', '~Adam_D._Cobb1.jsonl', '~Adam_Earle1.jsonl', '~Adam_Eck1.jsonl', '~Adam_Foster1.jsonl', '~Adam_Goodge1.jsonl', '~Adam_Ibrahim1.jsonl', '~Adam_Joseph_Riesselman1.jsonl', '~Adam_Lilja1.jsonl', '~Adam_Michael_Johansen1.jsonl', '~Adam_Polak1.jsonl', '~Adam_Prugel-Bennett1.jsonl', '~Adam_Scibior1.jsonl', '~Adam_Sealfon1.jsonl', '~Adam_Villaflor1.jsonl', '~Adam_W_Harley1.jsonl', '~Adarsh_Subbaswamy1.jsonl', '~Adel_Nabli1.jsonl', '~Adhiraj_Ghosh2.jsonl', '~Adhyyan_Manish_Narang1.jsonl', '~Adil_Zouitine1.jsonl', '~Aditi_Jha1.jsonl', '~Aditi_Krishnapriyan1.jsonl', '~Aditi_Mavalankar1.jsonl', '~Aditya_Balu1.jsonl', '~Aditya_Chattopadhyay1.jsonl', '~Aditya_Desai2.jsonl', '~Aditya_Ganeshan1.jsonl', '~Aditya_Gilra1.jsonl', '~Aditya_Golatkar1.jsonl', '~Aditya_Kanade2.jsonl', '~Aditya_Kumar_Akash1.jsonl', '~Aditya_Kusupati1.jsonl', '~Aditya_Makkar1.jsonl', '~Aditya_Modi1.jsonl', '~Aditya_Paliwal1.jsonl', '~Aditya_Prakash1.jsonl', '~Aditya_Ramesh2.jsonl', '~Aditya_Shrikant_Mate1.jsonl', '~Aditya_Vardhan_Varre1.jsonl', '~Adi_Haviv1.jsonl', '~Adnan_Siraj_Rakin2.jsonl', '~Adrian_Benton1.jsonl', '~Adrian_Bulat1.jsonl', '~Adriel_Saporta1.jsonl', '~Adrien_Bardes1.jsonl', '~Adrien_Benamira1.jsonl', '~Adrien_Corenflos1.jsonl', '~Adrien_Vacher1.jsonl', '~Advait_Harshal_Gadhikar1.jsonl', '~Advait_U_Parulekar1.jsonl', '~Adway_Mitra1.jsonl', '~Aerin_Kim1.jsonl', '~Afifa_Abduljabbar_Qahtan_Khaled1.jsonl', '~Afroditi_Papadaki1.jsonl', '~Afshin_Oroojlooyjadid1.jsonl', '~Aghiles_Salah1.jsonl', '~Agnieszka_Falenska1.jsonl', '~Ahana_Ghosh1.jsonl', '~Ahcene_Boubekki1.jsonl', '~Ahmad_Kazmi1.jsonl', '~Ahmad_Rashid1.jsonl', '~Ahmed_Abbas1.jsonl', '~Ahmed_Abdelkader_Abdelrazek1.jsonl', '~Ahmed_Elgohary3.jsonl', '~Ahmed_Khaled1.jsonl', '~Ahmed_MAZARI1.jsonl', '~Ahmet_Alacaoglu2.jsonl', '~Ahmet_Iscen3.jsonl', '~Aidan_Scannell1.jsonl', '~Aidong_Zhang2.jsonl', '~Aiham_Taleb1.jsonl', '~Aijun_Zhang2.jsonl', '~Ailing_Zeng1.jsonl', '~Ainhize_Barrainkua1.jsonl', '~Aiping_Liu1.jsonl', '~Aiqing_Zhu1.jsonl', '~Aishan_Liu1.jsonl', '~Aishwarya_Kamath1.jsonl', '~Aivar_Sootla1.jsonl', '~Ajaykumar_Unagar1.jsonl', '~Ajay_Divakaran1.jsonl', '~Ajay_Jaiswal1.jsonl', '~Ajil_Jalal1.jsonl', '~Ajinkya_K_Mulay2.jsonl', '~Ajinkya_Tejankar1.jsonl', '~Ajitesh_Srivastava1.jsonl', '~AJ_Piergiovanni1.jsonl', '~Akash_Abdu_Jyothi1.jsonl', '~Akash_Kumar_Dhaka1.jsonl', '~Akbir_Khan1.jsonl', '~Akhilan_Boopathy1.jsonl', '~Akhile ...

# %%
import pandas as pd

df = pd.DataFrame(liste_dicos, columns =['AuthorID', 'Title', 'Abstract'])
df = df.drop_duplicates()
df
# Out:
#                  AuthorID                                              Title  \
# 0         ~A.B._Siddique1  Linguistically-Enriched and Context-Aware Zero...
# 1         ~A.B._Siddique1  Generalized Zero-shot Intent Detection via Com...
# 2         ~A.B._Siddique1  Linguistically-Enriched and Context-AwareZero-...
# 3         ~A.B._Siddique1  Generalized Zero-shot Intent Detection via Com...
# 4      ~A._Sophia_Koepke1  Temporal and Cross-modal Attention for Audio-V...
# ...                   ...                                                ...
# 47510              ~正雄_罗1  From general to specific: Online updating for ...
# 47511              ~正雄_罗1  Approaching the Limit of Image Rescaling via F...
# 47512              ~正雄_罗1  From General to Specific: Online Updating for ...
# 47513              ~正雄_罗1  Approaching the Limit of Image Rescaling via F...
# 47514              ~正雄_罗1  Adaptive Dilated Convolution For Human Pose Es...
#
#                                                 Abstract
# 0      Slot filling is identifying contiguous spans o...
# 1      Identifying user intents from natural language...
# 2      Slot filling is identifying contiguous spans o...
# 3      Identifying user intents from natural language...
# 4      Audio-visual generalised zero-shot learning fo...
# ...                                                  ...
# 47510
# 47511  Image downscaling and upscaling are two basic ...
# 47512  Most deep learning-based super-resolution (SR)...
# 47513
# 47514  Most existing human pose estimation (HPE) meth...
#
# [46199 rows x 3 columns]

# %%
print(df.iloc[1617]['Abstract'])

# %%
title_list=[]
abstract_list=[]
for title, abstract in zip(df['Title'], df['Abstract']):
  title_list.append(title.encode("utf-8", "surrogatepass").decode("utf-8", "replace"))
  abstract_list.append(abstract.encode("utf-8", "surrogatepass").decode("utf-8", "replace"))

# %%
nouvodf=pd.DataFrame({'AuthorID': df['AuthorID'],'Title': title_list, 'Abstract': abstract_list})
nouvodf
# Out:
#                  AuthorID                                              Title  \
# 0         ~A.B._Siddique1  Linguistically-Enriched and Context-Aware Zero...
# 1         ~A.B._Siddique1  Generalized Zero-shot Intent Detection via Com...
# 2         ~A.B._Siddique1  Linguistically-Enriched and Context-AwareZero-...
# 3         ~A.B._Siddique1  Generalized Zero-shot Intent Detection via Com...
# 4      ~A._Sophia_Koepke1  Temporal and Cross-modal Attention for Audio-V...
# ...                   ...                                                ...
# 47510              ~正雄_罗1  From general to specific: Online updating for ...
# 47511              ~正雄_罗1  Approaching the Limit of Image Rescaling via F...
# 47512              ~正雄_罗1  From General to Specific: Online Updating for ...
# 47513              ~正雄_罗1  Approaching the Limit of Image Rescaling via F...
# 47514              ~正雄_罗1  Adaptive Dilated Convolution For Human Pose Es...
#
#                                                 Abstract
# 0      Slot filling is identifying contiguous spans o...
# 1      Identifying user intents from natural language...
# 2      Slot filling is identifying contiguous spans o...
# 3      Identifying user intents from natural language...
# 4      Audio-visual generalised zero-shot learning fo...
# ...                                                  ...
# 47510
# 47511  Image downscaling and upscaling are two basic ...
# 47512  Most deep learning-based super-resolution (SR)...
# 47513
# 47514  Most existing human pose estimation (HPE) meth...
#
# [46199 rows x 3 columns]

# %%
#save df
nouvodf.to_json('authors.json')

# %%
pd.read_json('authors.json')
# Out:
#                  AuthorID                                              Title  \
# 0         ~A.B._Siddique1  Linguistically-Enriched and Context-Aware Zero...
# 1         ~A.B._Siddique1  Generalized Zero-shot Intent Detection via Com...
# 2         ~A.B._Siddique1  Linguistically-Enriched and Context-AwareZero-...
# 3         ~A.B._Siddique1  Generalized Zero-shot Intent Detection via Com...
# 4      ~A._Sophia_Koepke1  Temporal and Cross-modal Attention for Audio-V...
# ...                   ...                                                ...
# 47510              ~正雄_罗1  From general to specific: Online updating for ...
# 47511              ~正雄_罗1  Approaching the Limit of Image Rescaling via F...
# 47512              ~正雄_罗1  From General to Specific: Online Updating for ...
# 47513              ~正雄_罗1  Approaching the Limit of Image Rescaling via F...
# 47514              ~正雄_罗1  Adaptive Dilated Convolution For Human Pose Es...
#
#                                                 Abstract
# 0      Slot filling is identifying contiguous spans o...
# 1      Identifying user intents from natural language...
# 2      Slot filling is identifying contiguous spans o...
# 3      Identifying user intents from natural language...
# 4      Audio-visual generalised zero-shot learning fo...
# ...                                                  ...
# 47510
# 47511  Image downscaling and upscaling are two basic ...
# 47512  Most deep learning-based super-resolution (SR)...
# 47513
# 47514  Most existing human pose estimation (HPE) meth...
#
# [46199 rows x 3 columns]

# %%
# !pip install -U adapters
from adapters import AutoAdapterModel
from transformers import AutoTokenizer
import torch
model = AutoAdapterModel.from_pretrained("allenai/specter2_base")
adapter_name = model.load_adapter("allenai/specter2", source="hf", set_active=True)
tokenizer = AutoTokenizer.from_pretrained('allenai/specter2_base')

#load base model
model = AutoAdapterModel.from_pretrained('allenai/specter2_base')

#load the adapter(s) as per the required task, provide an identifier for the adapter in load_as argument and activate it
model.load_adapter("allenai/specter2", source="hf", load_as="specter2", set_active=True)

# %%
import torch
from tqdm import tqdm  # Optional: for a nice progress bar


text_batch = [d['Title'].encode("utf-8", "surrogatepass").decode("utf-8", "replace") + tokenizer.sep_token + (d.get('Abstract').encode("utf-8", "surrogatepass").decode("utf-8", "replace") or '') for index,d in df.iterrows()]

# 1. Setup Device (GPU is much faster)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Processing on: {device}")

model.to(device)
model.eval()

maliste = []
batch_size = 32 # Try 16, 32, or 64 depending on your GPU VRAM

with torch.no_grad():
    # Loop through the data in chunks (batches)
    for i in tqdm(range(0, len(text_batch), batch_size)):
        #try:

        # Slice the batch
          batch_texts = text_batch[i : i + batch_size]

          # Tokenize the BATCH (padding applies to the longest in this specific batch)
          inputs = tokenizer(
              batch_texts,
              padding=True,
              truncation=True,
              return_tensors="pt",
              max_length=512
          ).to(device) # Move inputs to GPU

          output = model(**inputs)

          # Extract CLS token (embedding) and move back to CPU immediately to save VRAM
          cls_embeddings = output.last_hidden_state[:, 0, :].cpu()
          maliste.append(cls_embeddings)
        #except:
          #print(batch_texts)
# Optional: Concatenate list of tensors into one large tensor
final_embeddings = torch.cat(maliste, dim=0)

# %%
final_embeddings.shape

torch.save(final_embeddings,'authors.pt')
